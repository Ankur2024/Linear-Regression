# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankur2024/Linear-Regression/blob/main/Linear_Regression_Without_Using_Sklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing the libraries and datset**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

salary = pd.read_csv("Salary_Data.csv")
x = np.array(salary[['YearsExperience']])
y = np.array(salary[['Salary']])

plt.scatter(x, y)
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("X And Y Data")
plt.show()

# %%
x_mean = np.mean(x)
y_mean = np.mean(y)
print("Mean for x values is",x_mean)
print("Mean for y values is",y_mean)
# Out:
# Mean for x values is 5.3133333333333335
# Mean for y values is 76003.0

# %% [markdown]
# **To Calculate value of coeffcient and intercept**

# %%
num=0
den=0
for i in range(len(x)):
  num += (x[i]-x_mean)*(y[i]-y_mean)
  den += (x[i]-x_mean)**2

b1 = num/den
b0 = y_mean - (b1*x_mean)
print("The Intercept is ", float(b0[0]))
print("The coefficient is", float(b1[0]))
# Out:
# [9449.96232146] [25792.20019867]
# The Intercept is  25792.20019866869
# The coefficient is 9449.962321455077

# %%
y_preds=b0+b1*x
y_preds
# Out:
# array([[ 36187.15875227],
#        [ 38077.15121656],
#        [ 39967.14368085],
#        [ 44692.12484158],
#        [ 46582.11730587],
#        [ 53197.09093089],
#        [ 54142.08716303],
#        [ 56032.07962732],
#        [ 56032.07962732],
#        [ 60757.06078805],
#        [ 62647.05325234],
#        [ 63592.04948449],
#        [ 63592.04948449],
#        [ 64537.04571663],
#        [ 68317.03064522],
#        [ 72097.0155738 ],
#        [ 73987.00803809],
#        [ 75877.00050238],
#        [ 81546.97789525],
#        [ 82491.9741274 ],
#        [ 90051.94398456],
#        [ 92886.932681  ],
#        [100446.90253816],
#        [103281.8912346 ],
#        [108006.87239533],
#        [110841.86109176],
#        [115566.84225249],
#        [116511.83848464],
#        [123126.81210966],
#        [125016.80457395]])

# %%
plt.scatter(x,y)
plt.plot(x,y_preds,color='red')
plt.show()

# %% [markdown]
# R-square = 1-(SSR/SST)

# %%
num_r=0
den_r=0
for i in range(len(x)):
  num_r += (y[i]-y_preds[i]) ** 2
  den_r += (y[i]-y_mean) ** 2

r_square = 1-(num_r/den_r)
print("R-square is",float(r_square[0]))
# Out:
# R-square is 0.9569566641435086
